# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from utils import *

# %%
exclude_methods = [
    "LOG.0",
    "LOG.10",
    "LOG.3",
]


plot_scores_multiple_subplots(
    variable_name="alpha",
    metric="classification_score",
    uncertainty="se",
    pattern=None,
    diff_bayes=True,
    log_x=True,
    log_y=False,
    max_n_cols=3,
    min_y=-0.003,
    max_y=0.05,

    exclude_methods=exclude_methods,

    save_pdf="save_plots/Accuracy_PRC.pdf",

    #

)

# %%
exclude_methods = [
    "LOG.0",
    "LOG.10",
    "LOG.3",
]


plot_scores_multiple_subplots_pattern(

    metric="brier_score",
    uncertainty="se",
    pattern=[0,2,4],
    diff_bayes=True,
    log_x=True,
    log_y=False,
    max_n_cols=3,
    min_y=-0.003,
    max_y=0.05,

    exclude_methods=exclude_methods,

    save_pdf="save_plots/Brier_PATTERN.pdf",

    #

)
